# %% [markdown]
# <a href="https://colab.research.google.com/github/iosband/ts_tutorial/blob/master/ts_tutorial_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # A Tutorial on Thompson Sampling
#
# This colab notebook provides a way to play around with the code for [A Tutorial on Thompson Sampling](https://arxiv.org/abs/1707.02038) without needing to install anything.
#
# All of the underlying code is taken from the public git repository:
# https://github.com/iosband/ts_tutorial

# %% [markdown]
# ## Cloning the respository and setting up the environment
#
# Our code is made to work with Python 3.8 but would likely work with other versions.
#
# The commands below allow the package to be run in a default Google colab kernel.

# %%
#@title Cloning github repository and installing requied packaged
# %%capture
# !git clone https://github.com/iosband/ts_tutorial.git
# !pip install plotnine
# !pip install cvxpy

# %%
#@title Code assumes you are running from `ts_tutorial/src` directory
cd ts_tutorial/src
# Out:
# /content/ts_tutorial/src

# %% [markdown]
# ## Reproducing specific figures
#
# We present the exact code used to generate the figures for each plot in `reproduce_figures.py`.
#
# If you run this script with appropriate flags, you can reproduce the figures in the paper.

# %%
# !python reproduce_figures.py --help
# Out:
# usage: reproduce_figures.py [-h] [--figure FIGURE] [--run_frac RUN_FRAC]
#                             [--data_path DATA_PATH] [--plot_path PLOT_PATH]
#
# Reproduce figures.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --figure FIGURE       Figures to reproduce. Must be one of the following
#                         options: ['3.1', '3.2a', '3.2b', '4.1a', '4.1b',
#                         '4.3a', '4.3b', '5.1', '5.2a', '5.2b', '6.2', '6.3',
#                         '6.4', '7.1', '7.2', '7.3', '7.4', '7.5', 'all']
#   --run_frac RUN_FRAC   Proportion of paper experiments to run. Must be in [0,
#                         1].
#   --data_path DATA_PATH
#                         Path to store intermediate .csv files of experiment
#                         results. Must exist in OS.
#   --plot_path PLOT_PATH
#                         Path to store output paper plots. Must exist in OS.

# %% [markdown]
# ### Example = figure 3.1
#
# The code below will reproduces Figure 3.1 with 1% of the seeds of the paper, save output to /tmp/.
#
# We choose to run only 1% of the seeds in the interest of computational speed.

# %%
# !python reproduce_figures.py --figure=3.1 --run_frac=0.01 --data_path=/tmp/ --plot_path=/tmp/
# Out:
# ********************************************************************************
# Parsing Namespace(data_path='/tmp/', figure='3.1', plot_path='/tmp/', run_frac=0.01)
# WARNING - this can take a long time on a single machine... you may want to parallelize the jobs.
#
# ********************************************************************************
# Reproducing Figure 3.1, from TS Tutorial https://arxiv.org/abs/1707.02038
# With run_frac 0.01 this will launch 200 jobs, compared to 20000 in the paper.
# The config file with all necessary details of the underlying experiment is
#    finite_arm.config_simple.
# The experiment results are saved to /tmp/ with experiment_id finite_simple.
# The output plots are saved to /tmp/ with experiment_id finite_simple.
#
#
# ********************************************************************************
# Starting job 0 out of 200
# Starting job 1 out of 200
# Starting job 2 out of 200
# Starting job 3 out of 200
# Starting job 4 out of 200
# Starting job 5 out of 200
# Starting job 6 out of 200
# Starting job 7 out of 200
# Starting job 8 out of 200
# Starting job 9 out of 200
# Starting job 10 out of 200
# Starting job 11 out of 200
# Starting job 12 out of 200
# Starting job 13 out of 200
# Starting job 14 out of 200
# Starting job 15 out of 200
# Starting job 16 out of 200
# Starting job 17 out of 200
# Starting job 18 out of 200
# Starting job 19 out of 200
# Starting job 20 out of 200
# Starting job 21 out of 200
# Starting job 22 out of 200
# Starting job 23 out of 200
# Starting job 24 out of 200
# Starting job 25 out of 200
# Starting job 26 out of 200
# Starting job 27 out of 200
# Starting job 28 out of 200
# Starting job 29 out of 200
# Starting job 30 out of 200
# Starting job 31 out of 200
# Starting job 32 out of 200
# Starting job 33 out of 200
# Starting job 34 out of 200
# Starting job 35 out of 200
# Starting job 36 out of 200
# Starting job 37 out of 200
# Starting job 38 out of 200
# Starting job 39 out of 200
# Starting job 40 out of 200
# Starting job 41 out of 200
# Starting job 42 out of 200
# Starting job 43 out of 200
# Starting job 44 out of 200
# Starting job 45 out of 200
# Starting job 46 out of 200
# Starting job 47 out of 200
# Starting job 48 out of 200
# Starting job 49 out of 200
# Starting job 50 out of 200
# Starting job 51 out of 200
# Starting job 52 out of 200
# Starting job 53 out of 200
# Starting job 54 out of 200
# Starting job 55 out of 200
# Starting job 56 out of 200
# Starting job 57 out of 200
# Starting job 58 out of 200
# Starting job 59 out of 200
# Starting job 60 out of 200
# Starting job 61 out of 200
# Starting job 62 out of 200
# Starting job 63 out of 200
# Starting job 64 out of 200
# Starting job 65 out of 200
# Starting job 66 out of 200
# Starting job 67 out of 200
# Starting job 68 out of 200
# Starting job 69 out of 200
# Starting job 70 out of 200
# Starting job 71 out of 200
# Starting job 72 out of 200
# Starting job 73 out of 200
# Starting job 74 out of 200
# Starting job 75 out of 200
# Starting job 76 out of 200
# Starting job 77 out of 200
# Starting job 78 out of 200
# Starting job 79 out of 200
# Starting job 80 out of 200
# Starting job 81 out of 200
# Starting job 82 out of 200
# Starting job 83 out of 200
# Starting job 84 out of 200
# Starting job 85 out of 200
# Starting job 86 out of 200
# Starting job 87 out of 200
# Starting job 88 out of 200
# Starting job 89 out of 200
# Starting job 90 out of 200
# Starting job 91 out of 200
# Starting job 92 out of 200
# Starting job 93 out of 200
# Starting job 94 out of 200
# Starting job 95 out of 200
# Starting job 96 out of 200
# Starting job 97 out of 200
# Starting job 98 out of 200
# Starting job 99 out of 200
# Starting job 100 out of 200
# Starting job 101 out of 200
# Starting job 102 out of 200
# Starting job 103 out of 200
# Starting job 104 out of 200
# Starting job 105 out of 200
# Starting job 106 out of 200
# Starting job 107 out of 200
# Starting job 108 out of 200
# Starting job 109 out of 200
# Starting job 110 out of 200
# Starting job 111 out of 200
# Starting job 112 out of 200
# Starting job 113 out of 200
# Starting job 114 out of 200
# Starting job 115 out of 200
# Starting job 116 out of 200
# Starting job 117 out of 200
# Starting job 118 out of 200
# Starting job 119 out of 200
# Starting job 120 out of 200
# Starting job 121 out of 200
# Starting job 122 out of 200
# Starting job 123 out of 200
# Starting job 124 out of 200
# Starting job 125 out of 200
# Starting job 126 out of 200
# Starting job 127 out of 200
# Starting job 128 out of 200
# Starting job 129 out of 200
# Starting job 130 out of 200
# Starting job 131 out of 200
# Starting job 132 out of 200
# Starting job 133 out of 200
# Starting job 134 out of 200
# Starting job 135 out of 200
# Starting job 136 out of 200
# Starting job 137 out of 200
# Starting job 138 out of 200
# Starting job 139 out of 200
# Starting job 140 out of 200
# Starting job 141 out of 200
# Starting job 142 out of 200
# Starting job 143 out of 200
# Starting job 144 out of 200
# Starting job 145 out of 200
# Starting job 146 out of 200
# Starting job 147 out of 200
# Starting job 148 out of 200
# Starting job 149 out of 200
# Starting job 150 out of 200
# Starting job 151 out of 200
# Starting job 152 out of 200
# Starting job 153 out of 200
# Starting job 154 out of 200
# Starting job 155 out of 200
# Starting job 156 out of 200
# Starting job 157 out of 200
# Starting job 158 out of 200
# Starting job 159 out of 200
# Starting job 160 out of 200
# Starting job 161 out of 200
# Starting job 162 out of 200
# Starting job 163 out of 200
# Starting job 164 out of 200
# Starting job 165 out of 200
# Starting job 166 out of 200
# Starting job 167 out of 200
# Starting job 168 out of 200
# Starting job 169 out of 200
# Starting job 170 out of 200
# Starting job 171 out of 200
# Starting job 172 out of 200
# Starting job 173 out of 200
# Starting job 174 out of 200
# Starting job 175 out of 200
# Starting job 176 out of 200
# Starting job 177 out of 200
# Starting job 178 out of 200
# Starting job 179 out of 200
# Starting job 180 out of 200
# Starting job 181 out of 200
# Starting job 182 out of 200
# Starting job 183 out of 200
# Starting job 184 out of 200
# Starting job 185 out of 200
# Starting job 186 out of 200
# Starting job 187 out of 200
# Starting job 188 out of 200
# Starting job 189 out of 200
# Starting job 190 out of 200
# Starting job 191 out of 200
# Starting job 192 out of 200
# Starting job 193 out of 200
# Starting job 194 out of 200
# Starting job 195 out of 200
# Starting job 196 out of 200
# Starting job 197 out of 200
# Starting job 198 out of 200
# Starting job 199 out of 200
# ********************************************************************************
# Saving final plot to /tmp/finite_simple_ts_action.png
# This may not *precisely* match the paper due to run_frac 0.01
# ********************************************************************************
#
#
#
#
# /usr/local/lib/python3.6/dist-packages/plotnine/ggplot.py:729: PlotnineWarning: Saving 8 x 8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# /usr/local/lib/python3.6/dist-packages/plotnine/ggplot.py:730: PlotnineWarning: Filename: /tmp/finite_simple_ts_action.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# ********************************************************************************
# Saving final plot to /tmp/finite_simple_greedy_action.png
# This may not *precisely* match the paper due to run_frac 0.01
# ********************************************************************************
#
#
#
#
# /usr/local/lib/python3.6/dist-packages/plotnine/ggplot.py:729: PlotnineWarning: Saving 8 x 8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# /usr/local/lib/python3.6/dist-packages/plotnine/ggplot.py:730: PlotnineWarning: Filename: /tmp/finite_simple_greedy_action.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)

# %%
#@title All of the experimental data + plots have been saved to /tmp/
ls /tmp/
# Out:
# 'exp=finite_simple|id=0.csv'    'exp=finite_simple|id=192.csv'
# 'exp=finite_simple|id=100.csv'  'exp=finite_simple|id=193.csv'
# 'exp=finite_simple|id=101.csv'  'exp=finite_simple|id=194.csv'
# 'exp=finite_simple|id=102.csv'  'exp=finite_simple|id=195.csv'
# 'exp=finite_simple|id=103.csv'  'exp=finite_simple|id=196.csv'
# 'exp=finite_simple|id=104.csv'  'exp=finite_simple|id=197.csv'
# 'exp=finite_simple|id=105.csv'  'exp=finite_simple|id=198.csv'
# 'exp=finite_simple|id=106.csv'  'exp=finite_simple|id=199.csv'
# 'exp=finite_simple|id=107.csv'  'exp=finite_simple|id=19.csv'
# 'exp=finite_simple|id=108.csv'  'exp=finite_simple|id=1.csv'
# 'exp=finite_simple|id=109.csv'  'exp=finite_simple|id=20.csv'
# 'exp=finite_simple|id=10.csv'   'exp=finite_simple|id=21.csv'
# 'exp=finite_simple|id=110.csv'  'exp=finite_simple|id=22.csv'
# 'exp=finite_simple|id=111.csv'  'exp=finite_simple|id=23.csv'
# 'exp=finite_simple|id=112.csv'  'exp=finite_simple|id=24.csv'
# 'exp=finite_simple|id=113.csv'  'exp=finite_simple|id=25.csv'
# 'exp=finite_simple|id=114.csv'  'exp=finite_simple|id=26.csv'
# 'exp=finite_simple|id=115.csv'  'exp=finite_simple|id=27.csv'
# 'exp=finite_simple|id=116.csv'  'exp=finite_simple|id=28.csv'
# 'exp=finite_simple|id=117.csv'  'exp=finite_simple|id=29.csv'
# 'exp=finite_simple|id=118.csv'  'exp=finite_simple|id=2.csv'
# 'exp=finite_simple|id=119.csv'  'exp=finite_simple|id=30.csv'
# 'exp=finite_simple|id=11.csv'   'exp=finite_simple|id=31.csv'
# 'exp=finite_simple|id=120.csv'  'exp=finite_simple|id=32.csv'
# 'exp=finite_simple|id=121.csv'  'exp=finite_simple|id=33.csv'
# 'exp=finite_simple|id=122.csv'  'exp=finite_simple|id=34.csv'
# 'exp=finite_simple|id=123.csv'  'exp=finite_simple|id=35.csv'
# 'exp=finite_simple|id=124.csv'  'exp=finite_simple|id=36.csv'
# 'exp=finite_simple|id=125.csv'  'exp=finite_simple|id=37.csv'
# 'exp=finite_simple|id=126.csv'  'exp=finite_simple|id=38.csv'
# 'exp=finite_simple|id=127.csv'  'exp=finite_simple|id=39.csv'
# 'exp=finite_simple|id=128.csv'  'exp=finite_simple|id=3.csv'
# 'exp=finite_simple|id=129.csv'  'exp=finite_simple|id=40.csv'
# 'exp=finite_simple|id=12.csv'   'exp=finite_simple|id=41.csv'
# 'exp=finite_simple|id=130.csv'  'exp=finite_simple|id=42.csv'
# 'exp=finite_simple|id=131.csv'  'exp=finite_simple|id=43.csv'
# 'exp=finite_simple|id=132.csv'  'exp=finite_simple|id=44.csv'
# 'exp=finite_simple|id=133.csv'  'exp=finite_simple|id=45.csv'
# 'exp=finite_simple|id=134.csv'  'exp=finite_simple|id=46.csv'
# 'exp=finite_simple|id=135.csv'  'exp=finite_simple|id=47.csv'
# 'exp=finite_simple|id=136.csv'  'exp=finite_simple|id=48.csv'
# 'exp=finite_simple|id=137.csv'  'exp=finite_simple|id=49.csv'
# 'exp=finite_simple|id=138.csv'  'exp=finite_simple|id=4.csv'
# 'exp=finite_simple|id=139.csv'  'exp=finite_simple|id=50.csv'
# 'exp=finite_simple|id=13.csv'   'exp=finite_simple|id=51.csv'
# 'exp=finite_simple|id=140.csv'  'exp=finite_simple|id=52.csv'
# 'exp=finite_simple|id=141.csv'  'exp=finite_simple|id=53.csv'
# 'exp=finite_simple|id=142.csv'  'exp=finite_simple|id=54.csv'
# 'exp=finite_simple|id=143.csv'  'exp=finite_simple|id=55.csv'
# 'exp=finite_simple|id=144.csv'  'exp=finite_simple|id=56.csv'
# 'exp=finite_simple|id=145.csv'  'exp=finite_simple|id=57.csv'
# 'exp=finite_simple|id=146.csv'  'exp=finite_simple|id=58.csv'
# 'exp=finite_simple|id=147.csv'  'exp=finite_simple|id=59.csv'
# 'exp=finite_simple|id=148.csv'  'exp=finite_simple|id=5.csv'
# 'exp=finite_simple|id=149.csv'  'exp=finite_simple|id=60.csv'
# 'exp=finite_simple|id=14.csv'   'exp=finite_simple|id=61.csv'
# 'exp=finite_simple|id=150.csv'  'exp=finite_simple|id=62.csv'
# 'exp=finite_simple|id=151.csv'  'exp=finite_simple|id=63.csv'
# 'exp=finite_simple|id=152.csv'  'exp=finite_simple|id=64.csv'
# 'exp=finite_simple|id=153.csv'  'exp=finite_simple|id=65.csv'
# 'exp=finite_simple|id=154.csv'  'exp=finite_simple|id=66.csv'
# 'exp=finite_simple|id=155.csv'  'exp=finite_simple|id=67.csv'
# 'exp=finite_simple|id=156.csv'  'exp=finite_simple|id=68.csv'
# 'exp=finite_simple|id=157.csv'  'exp=finite_simple|id=69.csv'
# 'exp=finite_simple|id=158.csv'  'exp=finite_simple|id=6.csv'
# 'exp=finite_simple|id=159.csv'  'exp=finite_simple|id=70.csv'
# 'exp=finite_simple|id=15.csv'   'exp=finite_simple|id=71.csv'
# 'exp=finite_simple|id=160.csv'  'exp=finite_simple|id=72.csv'
# 'exp=finite_simple|id=161.csv'  'exp=finite_simple|id=73.csv'
# 'exp=finite_simple|id=162.csv'  'exp=finite_simple|id=74.csv'
# 'exp=finite_simple|id=163.csv'  'exp=finite_simple|id=75.csv'
# 'exp=finite_simple|id=164.csv'  'exp=finite_simple|id=76.csv'
# 'exp=finite_simple|id=165.csv'  'exp=finite_simple|id=77.csv'
# 'exp=finite_simple|id=166.csv'  'exp=finite_simple|id=78.csv'
# 'exp=finite_simple|id=167.csv'  'exp=finite_simple|id=79.csv'
# 'exp=finite_simple|id=168.csv'  'exp=finite_simple|id=7.csv'
# 'exp=finite_simple|id=169.csv'  'exp=finite_simple|id=80.csv'
# 'exp=finite_simple|id=16.csv'   'exp=finite_simple|id=81.csv'
# 'exp=finite_simple|id=170.csv'  'exp=finite_simple|id=82.csv'
# 'exp=finite_simple|id=171.csv'  'exp=finite_simple|id=83.csv'
# 'exp=finite_simple|id=172.csv'  'exp=finite_simple|id=84.csv'
# 'exp=finite_simple|id=173.csv'  'exp=finite_simple|id=85.csv'
# 'exp=finite_simple|id=174.csv'  'exp=finite_simple|id=86.csv'
# 'exp=finite_simple|id=175.csv'  'exp=finite_simple|id=87.csv'
# 'exp=finite_simple|id=176.csv'  'exp=finite_simple|id=88.csv'
# 'exp=finite_simple|id=177.csv'  'exp=finite_simple|id=89.csv'
# 'exp=finite_simple|id=178.csv'  'exp=finite_simple|id=8.csv'
# 'exp=finite_simple|id=179.csv'  'exp=finite_simple|id=90.csv'
# 'exp=finite_simple|id=17.csv'   'exp=finite_simple|id=91.csv'
# 'exp=finite_simple|id=180.csv'  'exp=finite_simple|id=92.csv'
# 'exp=finite_simple|id=181.csv'  'exp=finite_simple|id=93.csv'
# 'exp=finite_simple|id=182.csv'  'exp=finite_simple|id=94.csv'
# 'exp=finite_simple|id=183.csv'  'exp=finite_simple|id=95.csv'
# 'exp=finite_simple|id=184.csv'  'exp=finite_simple|id=96.csv'
# 'exp=finite_simple|id=185.csv'  'exp=finite_simple|id=97.csv'
# 'exp=finite_simple|id=186.csv'  'exp=finite_simple|id=98.csv'
# 'exp=finite_simple|id=187.csv'  'exp=finite_simple|id=99.csv'
# 'exp=finite_simple|id=188.csv'  'exp=finite_simple|id=9.csv'
# 'exp=finite_simple|id=189.csv'  'exp=finite_simple|params.csv'
# 'exp=finite_simple|id=18.csv'    finite_simple_greedy_action.png
# 'exp=finite_simple|id=190.csv'   finite_simple_ts_action.png
# 'exp=finite_simple|id=191.csv'

# %%
#@title Action selections for the greedy agent
from IPython import display
display.Image('/tmp/finite_simple_greedy_action.png')

# %%
#@title Action selection for the TS agent
display.Image('/tmp/finite_simple_ts_action.png')

# %% [markdown]
# Note that these results do not *exactly* reproduce the paper due to the smaller number of seeds (for speed).

# %% [markdown]
# ## Understanding the underlying experiment code
#
# This section runs through the `local_runner.py` and shows how the underlying code is used.
#
# Agent settings are defined in a `config` file, and then the "runner" loops through the different agents and evaluation

# %%
#@title Imports (double-click to show/hide)
import importlib
import os
import sys
from base import config_lib
import numpy as np
import pandas as pd
import plotnine as gg

# %% [markdown]
# The list of experiment configs in the paper is given:
#
# ```
# ['finite_arm.config_simple', 'finite_arm.config_simple_rand', 'finite_arm.config_simple_sanity', 'finite_arm.config_misspecified', 'finite_arm.config_drift', 'cascading.config_cascading', 'ensemble_nn.config_nn', 'graph.config_indep', 'graph.config_indep_binary', 'graph.config_correlated', 'graph.config_correlated_sanity']
# ```
#
# You can explore each setting in the relevant file of source code.

# %%
#@title Set these variables to run from pre-populated config
CONFIG_PATH = 'finite_arm.config_simple' #@param
N_JOBS = 100 #@param

# %%
#@title Pulling in that config file and running these agents
# Running from a local config file
sys.path.append(os.getcwd())

# Loading in the experiment config file
config_module = importlib.import_module(CONFIG_PATH)
config = config_module.get_config()

results = []
for job_id in range(N_JOBS):
  # Running the experiment.
  job_config = config_lib.get_job_config(config, job_id)
  experiment = job_config['experiment']
  experiment.run_experiment()
  results.append(experiment.results)

# %%
#@title Plotting and analysis (uses plotnine by default)

# Collating data from experiments results with Pandas
params_df = config_lib.get_params_df(config)
df = pd.merge(pd.concat(results), params_df, on='unique_id')
plt_df = (df.groupby(['agent', 't'])
          .agg({'instant_regret': np.mean})
          .reset_index())

# Set up a simple plot
gg.theme_set(gg.theme_bw(base_size=16, base_family='serif'))
gg.theme_update(figure_size=(12, 8))

p = (gg.ggplot(plt_df)
     + gg.aes('t', 'instant_regret', colour='agent')
     + gg.geom_line())
print(p)
# Out:
# <ggplot: (8749007193769)>

# %% [markdown]
# Code for analysing and plotting agents is given in `base/plot.py` and if you use `reproduce_figures.py` will be called automatically.

# %% [markdown]
# ## Running agents and environments without a config
#
#
# Our code is meant to be as simple as possible, optimizing for ease of use rather than speed.
#
# We break the experiments/algorithms into three key parts:
#
# - `agent`: handles learning + action selection of a bandit algorithm.
# - `environment`: evaluates rewards/outcomes from an action.
# - `experiment`: contains agent, environment and seed.

# %%
#@title Running a very simple agent on a finite armed bandit
from base.experiment import BaseExperiment
from finite_arm.agent_finite import FiniteBernoulliBanditTS
from finite_arm.env_finite import FiniteArmedBernoulliBandit

probs = [0.7, 0.8, 0.9]  #@param
n_steps = 1000  #@param
seed = 0  #@param

agent = FiniteBernoulliBanditTS(n_arm=len(probs))
env = FiniteArmedBernoulliBandit(probs)
experiment = BaseExperiment(
    agent, env, n_steps=n_steps, seed=seed, unique_id='example')

experiment.run_experiment()

# %%
#@title Simple display / plot of results

print(experiment.results.head())

p = (gg.ggplot(experiment.results)
     + gg.aes(x='t', y='cum_regret / t', colour='unique_id')
     + gg.geom_line())
print(p)
# Out:
#    t  instant_regret  cum_regret  action unique_id
# 0  1             0.2         0.2       0   example
# 1  2             0.1         0.3       1   example
# 2  3             0.2         0.5       0   example
# 3  4             0.2         0.7       0   example
# 4  5             0.2         0.9       0   example
# <ggplot: (8748996455358)>
